# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from helper import get_data_markets

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

import statsmodels.api as sm

# %%
TICKER_NAME = '^DJI'
interval = '1d'

start_date = '2018-10-18'
end_date = '2022-10-18'

# %%
df = get_data_markets(ticker=TICKER_NAME, interval=interval, start_date=start_date, end_date=end_date, source='yahoo')
df.shape
# Out:
# (1006, 8)

# %%
df_to_test = get_data_markets(ticker=TICKER_NAME, interval=interval, start_date='2021-11-18', end_date='2023-11-18', source='yahoo')
df_to_test.shape
# Out:
# (487, 8)

# %%
df.head()
# Out:
#            Open          High           Low         Close
# 0  25645.560547  25691.460938  25236.009766  25379.449219
# 1  25421.089844  25608.710938  25350.019531  25444.339844
# 2  25492.140625  25561.339844  25236.050781  25317.410156
# 3  25038.460938  25307.699219  24768.789062  25191.429688
# 4  25172.880859  25306.230469  24533.189453  24583.419922

# %%
df = df[df.columns[1:5]]
df
# Out:
#               High           Low         Close
# 0     25691.460938  25236.009766  25379.449219
# 1     25608.710938  25350.019531  25444.339844
# 2     25561.339844  25236.050781  25317.410156
# 3     25307.699219  24768.789062  25191.429688
# 4     25306.230469  24533.189453  24583.419922
# ...            ...           ...           ...
# 1001  29608.419922  29074.230469  29239.189453
# 1002  29455.119141  29136.029297  29210.849609
# 1003  30168.539062  28660.939453  30038.720703
# 1004  30428.820312  29614.300781  29634.830078
# 1005  30311.949219  29997.619141  30185.820312
#
# [1006 rows x 3 columns]

# %%
dataset = df.to_numpy()
dataset.shape
# Out:
# (1006, 3)

# %%
def get_training(df: pd.DataFrame, period: int) -> 'tuple(np.array)':
    close_prices = df['Close'].values
    samples, gts = [], []
    for i in range(period, len(close_prices)-1):
        samples.append(close_prices[i-period: i])
        gts.append(close_prices[i+1])

    return samples, gts

# %% [markdown]
# # Period = 250 days

# %%
period = 250

train_x, train_y = get_training(df, period)
val_x, val_y = get_training(df_to_test, period)

# %%
lin_reg = LinearRegression().fit(train_x, train_y)
prediction = lin_reg.predict(val_x)

# %%
coef = lin_reg.coef_
bias = lin_reg.intercept_
coef.shape, bias
# Out:
# ((250,), 443.72313341855624)

# %%
plt.figure(figsize=(7,3))
regression = []

dates = df_to_test['Date'].values

plt.plot(dates[-236:], val_y, label='close prices')
print([lin_reg.predict([val_x[0]]), lin_reg.predict([val_x[-1]])])
plt.plot([dates[-236], dates[-1]], [lin_reg.predict([val_x[0]]), lin_reg.predict([val_x[-1]])], label='prediction trend')

# plt.plot(regression, color='red')
plt.xticks(rotation=30)
plt.xlabel('Дата')
plt.ylabel('Средняя цена')

plt.legend()
plt.show()
# Out:
# [array([33664.80880594]), array([33174.633128])]

# %%
start, end = (lin_reg.predict([val_x[0]]), lin_reg.predict([val_x[-1]]))

# %%
tan = (end - start) / (val_x[-1][0] - val_x[0][0])
tan
# Out:
# array([0.12157618])

# %%
b = end - tan * val_x[0][0]
b
# Out:
# array([28813.58022581])

# %%
ups, downs = np.zeros(len(val_x[-1])), np.zeros(len(val_x[-1]))
treshold = 1e-2

for idx, x in enumerate(val_x[-1]):
    _x = x * tan + b
    if x - _x > treshold:
        ups[idx] += 1
    elif x - _x <= -treshold:
        downs[idx] += 1

# %%
print(ups.sum(), downs.sum())
# Out:
# 221.0 29.0

# %%
print(f'fitted ratio = {(len(val_x[-1]) - ups.sum() - downs.sum()) / len(val_x[-1])}' +\
      f'\toutfitted ratio = {(ups.sum() + downs.sum()) / len(val_x[-1])}')
# Out:
# fitted ratio = 0.0	outfitted ratio = 1.0

# %%
close_prices = df_to_test['Close'].values

# %%
fitted = close_prices * tan + b
residuals = close_prices - fitted
# TODO make points and sen calculate residuals

# %%
predicted = lin_reg.predict(val_x)

# %%
dates.shape, predicted.shape
# Out:
# ((487,), (236,))

# %%
plt.figure(figsize=(10, 3))

plt.plot(dates[-len(predicted):], fitted[-len(predicted):], label='trend', color='red')
plt.plot(dates[-len(predicted):], predicted, label='predicted', color='orange')
plt.plot(dates[-len(predicted):], close_prices[-len(predicted):], label='gt', color='blue')

plt.xticks(rotation=30)
plt.xlabel('Дата')
plt.ylabel('Средняя цена')

plt.legend()
plt.show()

# %% [markdown]
# ## Residuals vs Fitted

# %%
import seaborn as sns

data = {'fitted': close_prices[-len(predicted):] - predicted, 'gt': close_prices[-len(predicted):] }

plt.figure(figsize=(10,3))
fig = sns.residplot(x='fitted', y='gt', data=data,
                    lowess=True,
                    scatter_kws={'alpha': 0.5},
                    line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8}) 
plt.title('Residual VS Fitted')
plt.xlabel('Close prices in USD')
plt.ylabel('Residuals in USD')
# plt.yscale('log')
plt.show()

# %% [markdown]
# ## Normal Q-Q

# %%
import statsmodels.api as sm

# %%
residuals = close_prices[-len(predicted):] - predicted
fig = sm.qqplot((residuals - np.min(residuals)) / (np.max(residuals) - np.min(residuals)), line='45')
plt.title('Normal Q-Q')
plt.show()

"""
    Чем лучше точки ложатся на красную линию, тем распределение точек остатков более
    похоже на нормальное, но здесь видим, что линия точек немного отклонена от горизонтали,
    значит распределение цен закрытия временного ряда слабо похоже на нормальное
"""
# Out:
# '\n    Чем лучше точки ложатся на красную линию, тем распределение точек остатков более\n    похоже на нормальное, но здесь видим, что линия точек немного отклонена от горизонтали,\n    значит распределение цен закрытия временного ряда слабо похоже на нормальное\n'

# %% [markdown]
# ## Scale-Location

# %%
residuals = close_prices[-len(predicted):] - predicted
# norm_abs_sqrt_residuals = np.sqrt(np.abs(residuals))
norm_abs_sqrt_residuals = np.sqrt(np.abs((residuals - np.min(residuals)) / (np.max(residuals) - np.min(residuals))))

fig = plt.figure()
plt.scatter(predicted, norm_abs_sqrt_residuals, alpha=0.5)

data_to_plot = {'fitted': close_prices[-len(predicted):], 'norm_resid': norm_abs_sqrt_residuals}
sns.regplot(data=data_to_plot, x='fitted', y='norm_resid',
              scatter=False,
              ci=False,
              lowess=True,
              line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})

indexes = np.argsort(norm_abs_sqrt_residuals)
_fitted = fitted[indexes]
_residuals = norm_abs_sqrt_residuals[indexes]

plt.xlabel('fitted in USD')
plt.ylabel('sqrt(|norm_residuals|)')
plt.title('Scale - Location')

plt.show()

# %% [markdown]
# ## Residuals vs Leverage

# %%
model = sm.OLS(train_y, sm.add_constant(train_x)).fit()
sm.graphics.influence_plot(model, criterion="cooks")
plt.show()

"""
    Этот типа графика показывает, насколько сильно влияют те или иные фичи на предсказание модели
    В нашем случае фича - это измерение - величина цены закрытия актива в конкретный день
    Как и предполагалось, раз это временной ряд - выбросив одно наблюдение модель должна сильно отреагировать
"""
# Out:
# '\n    Этот типа графика показывает, насколько сильно влияют те или иные фичи на предсказание модели\n    В нашем случае фича - это измерение - величина цены закрытия актива в конкретный день\n    Как и предполагалось, раз это временной ряд - выбросив одно наблюдение модель должна сильно отреагировать\n'
